# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Ros/Simulacion-1/blob/main/N%C3%BAmeros_Aleatorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MEDIOS CUADRADOS**

# %%
#INGRESA SEMILLA
semilla = int(input("Ingrese una semilla de 4 dígitos: "))

#CORRIGE NUMERO SI NO ES DE 4 CIFRAS
while semilla < 1000 or semilla > 9999:
    semilla = int(input("Ingrese una semilla de 4 dígitos: "))

xi = semilla
pi = xi ** 2
print("\nn        xn           xn^2     \n")    #TABLA
print(f"0        {xi}         {pi}")

for i in range(1, 21):
    pi = xi ** 2
    st1 = str(pi)
    dig = len(st1)
    if dig == 8:                   #NO. DE CIFRA DEL PRODUCTO ES 8
        xii = st1[2:6]
        pi = int(xii) ** 2
    else:                          #NO. DE CIFRA DEL PRODUCTO NO ES 8
        xii = st1[1:5]
        pi = int(xii) ** 2

    if len(xii) < 4:
        xii = '0' + xii            #RELLENA CON 0

    if len(str(pi)) % 2 != 0:
        pi = '0' + str(pi)         #RELLENA CON 0

#IMPRIME NUMEROS
    if i < 10:
        print(f"{i}        {xii}         {pi}")
    else:
        print(f"{i}       {xii}         {pi}")

    xi = int(xii)
# Out:
# Ingrese una semilla de 4 dígitos: 9162
#
# n        xn           xn^2
#
# 0        9162         83942244
# 1        9422         88774084
# 2        7740         59907600
# 3        9076         82373776
# 4        3737         13965169
# 5        9651         93141801
# 6        1418         02010724
# 7        0107         011449
# 8        1449         02099601
# 9        0996         992016
# 10       9201         84658401
# 11       6584         43349056
# 12       3490         12180100
# 13       1801         03243601
# 14       2436         05934096
# 15       9340         87235600
# 16       2356         05550736
# 17       5507         30327049
# 18       3270         10692900
# 19       6929         48011041
# 20       0110         012100

# %% [markdown]
# # **PRODUCTO MEDIO**

# %%
#NUMERO GENERADOS Y NUMERO DE CIFRAS
num=int(input('No. de números aleatorios: '))
d=int(input("Ingrese la longitud del número: "))

xn_1=int(input("Xn_1= "))
xn=int(input("Xn= "))

#CORRIGE NUMEROS
while len(str(xn))!=d:
  xn=int(input("\nXn= "))

while len(str(xn_1))!=d:
  xn_1=int(input("Xn_1= "))

#TABLA
print("\nn          xn_1           xn           (xn)(xn_1)\n")

for i in range(0,num):
  prod=xn*xn_1
  prod=str(prod)
  lprod=len(str(prod))

  if (lprod-d)%2!=0:
    lprod=len('0'+prod)
    prod='0'+prod          #Agrega 0 para tomar cifra de enmedio
  inter=int((lprod-d)/2)
  x=prod[inter:inter+d]    #Elimina extremos

  sxn=str(xn)
  sxn_1=str(xn_1)

#CORRIGE TABLA
  while len(sxn)<d:
    sxn='0'+sxn             #Rellena con 0

  while len(sxn_1)<d:
    sxn_1='0'+sxn_1         #Rellena con 0

#IMPRIME NÚMEROS
  if i>9:
    print(f"{i}         {sxn_1}          {sxn}           {prod}")
  else:
    print(f"{i}          {sxn_1}          {sxn}           {prod}")

  xn_1=xn
  xn=int(x)
# Out:
# No. de números aleatorios: 20
# Ingrese la longitud del número: 5
# Xn_1= 12343
# Xn= 12678
#
# n          xn_1           xn           (xn)(xn_1)
#
# 0          12343          12678           156484554
# 1          12678          64845           822104910
# 2          64845          21049           01364922405
# 3          21049          64922           01366543178
# 4          64922          66543           04320104646
# 5          66543          20104           01337780472
# 6          20104          37780           759529120
# 7          37780          95291           03600093980
# 8          95291          00093           8862063
# 9          00093          86206           8017158
# 10         86206          01715           147843290
# 11         01715          78432           134510880
# 12         78432          45108           03537910656
# 13         45108          37910           01710044280
# 14         37910          10044           380768040
# 15         10044          07680           077137920
# 16         07680          71379           548190720
# 17         71379          81907           05846439753
# 18         81907          46439           03803679173
# 19         46439          03679           170849081

# %% [markdown]
# # **MÉTODO DE CONGRUENCIA**

# %%
#INGRESA SEMILLA Y CONSTANTES
#iter=int(input("Cantidad de números aleatorios: "))
iter=100
xn=6
a=5
c=7
m=11311
print("\nN     Xn           aXn+c      aXn+c mod 16      Xn/16\n")
for i in range(0,iter):
  prod=(a*xn+c)
  mod=prod%m
  xn1=mod/m
  #IMPRIME TABLA
  print(f"{i: <3}   {xn: <10}    {prod: <10}    {mod: <10}   {xn/m: <10}")
  xn=mod
# Out:
# N     Xn           aXn+c      aXn+c mod 16      Xn/16
#
# 0     6             37            37           0.0005304570771815047
# 1     37            192           192          0.0032711519759526125
# 2     192           967           967          0.01697462646980815
# 3     967           4842          4842         0.08549199893908585
# 4     4842          24217         1595         0.42807886128547434
# 5     1595          7982          7982         0.14101317301741667
# 6     7982          39917         5984         0.7056847316771284
# 7     5984          29927         7305         0.5290425249756874
# 8     7305          36532         2599         0.645831491468482
# 9     2599          13002         1691         0.22977632393245515
# 10    1691          8462          8462         0.14950048625232076
# 11    8462          42317         8384         0.7481212978516488
# 12    8384          41927         7994         0.7412253558482893
# 13    7994          39977         6044         0.7067456458314915
# 14    6044          30227         7605         0.5343470957475024
# 15    7605          38032         4099         0.6723543453275572
# 16    4099          20502         9191         0.3623905932278313
# 17    9191          45962         718          0.8125718327292016
# 18    718           3597          3597         0.0634780302360534
# 19    3597          17992         6681         0.3180090177703121
# 20    6681          33412         10790        0.5906639554416055
# 21    10790         53957         8713         0.9539386437980727
# 22    8713          43572         9639         0.7703120855804084
# 23    9639          48202         2958         0.8521792944920874
# 24    2958          14797         3486         0.26151533905048185
# 25    3486          17437         6126         0.3081955618424542
# 26    6126          30637         8015         0.5415966758023163
# 27    8015          40082         6149         0.7086022456016268
# 28    6149          30752         8130         0.5436300945981788
# 29    8130          40657         6724         0.7187693395809389
# 30    6724          33627         11005        0.5944655644947396
# 31    11005         55032         9788         0.9729466890637433
# 32    9788          48947         3703         0.8653523119087614
# 33    3703          18522         7211         0.327380426133852
# 34    7211          36062         2129         0.6375209972593051
# 35    2129          10652         10652        0.1882238528865706
# 36    10652         53267         8023         0.941738131022898
# 37    8023          40122         6189         0.7093095217045354
# 38    6189          30952         8330         0.5471664751127221
# 39    8330          41657         7724         0.7364512421536558
# 40    7724          38627         4694         0.6828750773583238
# 41    4694          23477         855          0.41499425338166385
# 42    855           4282          4282         0.07559013349836442
# 43    4282          21417         10106        0.3785695340818672
# 44    10106         50537         5293         0.8934665369993812
# 45    5293          26472         3850         0.46795155158695073
# 46    3850          19257         7946         0.3403766245247989
# 47    7946          39737         5804         0.7025019892140394
# 48    5804          29027         6405         0.5131288126602422
# 49    6405          32032         9410         0.5662629298912563
# 50    9410          47057         1813         0.8319335160463266
# 51    1813          9072          9072         0.160286446821678
# 52    9072          45367         123          0.8020511006984351
# 53    123           622           622          0.010874370082220848
# 54    622           3117          3117         0.054990717001149325
# 55    3117          15592         4281         0.2755724515957917
# 56    4281          21412         10101        0.3784811245690036
# 57    10101         50512         5268         0.8930244894350632
# 58    5268          26347         3725         0.46574131376536115
# 59    3725          18632         7321         0.32932543541685083
# 60    7321          36612         2679         0.6472460436742994
# 61    2679          13402         2091         0.23684908496154186
# 62    2091          10462         10462        0.1848642913977544
# 63    10462         52317         7073         0.9249403235788171
# 64    7073          35372         1439         0.6253204844841305
# 65    1439          7202          7202         0.12722128901069754
# 66    7202          36017         2084         0.6367253116435329
# 67    2084          10427         10427        0.1842454248077093
# 68    10427         52142         6898         0.9218459906285916
# 69    6898          34497         564          0.6098488197330033
# 70    564           2827          2827         0.049862965255061446
# 71    2827          14142         2831         0.2499336928653523
# 72    2831          14162         2851         0.25028733091680666
# 73    2851          14262         2951         0.2520555211740783
# 74    2951          14762         3451         0.26089647246043673
# 75    3451          17262         5951         0.3051012288922288
# 76    5951          29762         7140         0.5261250110511891
# 77    7140          35707         1774         0.6312439218459907
# 78    1774          8877          8877         0.15683847581999824
# 79    8877          44392         10459        0.7848112456900362
# 80    10459         52302         7058         0.9246750950402264
# 81    7058          35297         1364         0.6239943417911767
# 82    1364          6827          6827         0.12059057554592874
# 83    6827          34142         209          0.6035717443196889
# 84    209           1052          1052         0.01847758818848908
# 85    1052          5267          5267         0.09300680753249049
# 86    5267          26342         3720         0.46565290425249756
# 87    3720          18607         7296         0.32888338785253296
# 88    7296          36487         2554         0.6450358058527097
# 89    2554          12777         1466         0.22579789585359383
# 90    1466          7337          7337         0.1296083458580143
# 91    7337          36692         2759         0.6486605958801167
# 92    2759          13802         2491         0.2439218459906286
# 93    2491          12462         1151         0.22022809654318803
# 94    1151          5762          5762         0.10175934930598532
# 95    5762          28817         6195         0.5094156131199717
# 96    6195          30982         8360         0.5476969321899037
# 97    8360          41807         7874         0.7391035275395632
# 98    7874          39377         5444         0.6961365042878613
# 99    5444          27227         4605         0.48130138802935196

# %% [markdown]
# *m define el ciclo de vida de los números aleatorios generados, ya que se está trabajando con la operación modulo (entre mas grande sea m, mayor será la cantidad de residuos posibles, funciona mejor para m muy grande o para m siendo un número primo)*
